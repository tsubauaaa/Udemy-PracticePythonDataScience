# %%
import numpy as np
import pandas as pd
from pandas import Series,DataFrame

# %%
dframe_wine = pd.read_csv('winequality-red.csv',sep=';')

# %%
dframe_wine.head()
# Out:
#    fixed acidity  volatile acidity   ...     alcohol  quality
# 0            7.4              0.70   ...         9.4        5
# 1            7.8              0.88   ...         9.8        5
# 2            7.8              0.76   ...         9.8        5
# 3           11.2              0.28   ...         9.8        6
# 4            7.4              0.70   ...         9.4        5
#
# [5 rows x 12 columns]

# %%
# 平均アルコール度数
dframe_wine['alcohol'].mean()
# Out:
# 10.422983114446502

# %%
def max_to_min(arr):
    return arr.max() - arr.min()

# %%
wino = dframe_wine.groupby('quality')
wino.describe()
# Out:
#         alcohol                            ...   volatile acidity
#           count       mean       std  min  ...                25%    50%     75%    max
# quality                                    ...
# 3          10.0   9.955000  0.818009  8.4  ...             0.6475  0.845  1.0100  1.580
# 4          53.0  10.265094  0.934776  9.0  ...             0.5300  0.670  0.8700  1.130
# 5         681.0   9.899706  0.736521  8.5  ...             0.4600  0.580  0.6700  1.330
# 6         638.0  10.629519  1.049639  8.4  ...             0.3800  0.490  0.6000  1.040
# 7         199.0  11.465913  0.961933  9.2  ...             0.3000  0.370  0.4850  0.915
# 8          18.0  12.094444  1.224011  9.8  ...             0.3350  0.370  0.4725  0.850
#
# [6 rows x 88 columns]

# %%
# aggに関数を渡す
wino.agg(max_to_min)
# Out:
#          fixed acidity  volatile acidity   ...     sulphates  alcohol
# quality                                    ...
# 3                  4.9             1.140   ...          0.46      2.6
# 4                  7.9             0.900   ...          1.67      4.1
# 5                 10.9             1.150   ...          1.61      6.4
# 6                  9.6             0.880   ...          1.55      5.6
# 7                 10.7             0.795   ...          0.97      4.8
# 8                  7.6             0.590   ...          0.47      4.2
#
# [6 rows x 11 columns]

# %%
# aggに文字列を渡す
wino.agg('mean')
# Out:
#          fixed acidity  volatile acidity    ...      sulphates    alcohol
# quality                                     ...
# 3             8.360000          0.884500    ...       0.570000   9.955000
# 4             7.779245          0.693962    ...       0.596415  10.265094
# 5             8.167254          0.577041    ...       0.620969   9.899706
# 6             8.347179          0.497484    ...       0.675329  10.629519
# 7             8.872362          0.403920    ...       0.741256  11.465913
# 8             8.566667          0.423333    ...       0.767778  12.094444
#
# [6 rows x 11 columns]

# %%
dframe_wine.head()
# Out:
#    fixed acidity  volatile acidity   ...     alcohol  quality
# 0            7.4              0.70   ...         9.4        5
# 1            7.8              0.88   ...         9.8        5
# 2            7.8              0.76   ...         9.8        5
# 3           11.2              0.28   ...         9.8        6
# 4            7.4              0.70   ...         9.4        5
#
# [5 rows x 12 columns]

# %%
# 新しい列を付け加える
dframe_wine['qual/alc ratio'] = dframe_wine['quality'] / dframe_wine['alcohol']
dframe_wine.head()
# Out:
#    fixed acidity  volatile acidity       ...        quality  qual/alc ratio
# 0            7.4              0.70       ...              5        0.531915
# 1            7.8              0.88       ...              5        0.510204
# 2            7.8              0.76       ...              5        0.510204
# 3           11.2              0.28       ...              6        0.612245
# 4            7.4              0.70       ...              5        0.531915
#
# [5 rows x 13 columns]

# %%
# groupbyの代わりにpivot_tableを使う
dframe_wine.pivot_table(index=['quality'])
# Out:
#            alcohol        ...         volatile acidity
# quality                   ...
# 3         9.955000        ...                 0.884500
# 4        10.265094        ...                 0.693962
# 5         9.899706        ...                 0.577041
# 6        10.629519        ...                 0.497484
# 7        11.465913        ...                 0.403920
# 8        12.094444        ...                 0.423333
#
# [6 rows x 12 columns]

# %%
# %matplotlib inline
dframe_wine.plot(kind='scatter',x='quality',y='alcohol')
