# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

from scipy import stats

mean = 0

std = 1

# 便宜的に領域を決める
X = np.arange(-4,4,0.01)

Y = stats.norm.pdf(X,mean,std)

plt.plot(X,Y)

# %%
import numpy as np

mu,sigma = 0,0.1

# 正規分布に従う乱数を1000個生成
norm_set = np.random.normal(mu,sigma,1000)

# %%
import seaborn as sns
plt.hist(norm_set,bins=50)
# Out:
# (array([ 1.,  0.,  1.,  2.,  1.,  5.,  9.,  8.,  3., 14.,  8., 11., 20.,
#         29., 28., 46., 28., 48., 34., 36., 34., 46., 51., 47., 52., 52.,
#         55., 40., 39., 41., 30., 35., 24., 30., 26., 12., 14., 14.,  5.,
#          4.,  7.,  1.,  3.,  0.,  1.,  1.,  0.,  2.,  1.,  1.]),
#  array([-2.92815194e-01, -2.80611762e-01, -2.68408330e-01, -2.56204898e-01,
#         -2.44001466e-01, -2.31798033e-01, -2.19594601e-01, -2.07391169e-01,
#         -1.95187737e-01, -1.82984304e-01, -1.70780872e-01, -1.58577440e-01,
#         -1.46374008e-01, -1.34170575e-01, -1.21967143e-01, -1.09763711e-01,
#         -9.75602785e-02, -8.53568463e-02, -7.31534140e-02, -6.09499818e-02,
#         -4.87465496e-02, -3.65431173e-02, -2.43396851e-02, -1.21362528e-02,
#          6.71794323e-05,  1.22706117e-02,  2.44740439e-02,  3.66774762e-02,
#          4.88809084e-02,  6.10843407e-02,  7.32877729e-02,  8.54912052e-02,
#          9.76946374e-02,  1.09898070e-01,  1.22101502e-01,  1.34304934e-01,
#          1.46508366e-01,  1.58711799e-01,  1.70915231e-01,  1.83118663e-01,
#          1.95322095e-01,  2.07525528e-01,  2.19728960e-01,  2.31932392e-01,
#          2.44135824e-01,  2.56339257e-01,  2.68542689e-01,  2.80746121e-01,
#          2.92949553e-01,  3.05152986e-01,  3.17356418e-01]),
#  <a list of 50 Patch objects>)
